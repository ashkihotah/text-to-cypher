# %%
import pandas as pd

# %%
model = "gemma-2-9b-it" # "gpt-4.1", "gemma-2-9b-it", "llama3.1-8b"
path = f"../data/interim/predictions/neo4j-2024v1/{model}/test.csv"
df = pd.read_csv(path)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2471 entries, 0 to 2470
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   df.index                  2471 non-null   int64
#  1   rows_file                 2244 non-null   object
#  2   syntax_error              2464 non-null   object
#  3   is_less_than_limit_50000  2264 non-null   object
#  4   is_timeout_expired        2471 non-null   bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 79.8+ KB

# %%
print("Failed predictions:", df["rows_file"].isna().sum())
print(f"Success rate: {(df["rows_file"].notna().sum() / len(df)) * 100:.2f}%")
print("syntax_errors:", (df["syntax_error"] == True).sum())
print("is_less_than_limit_50000 == False:", (df["is_less_than_limit_50000"] == False).sum())
print("is_timeout_expired:", (df["is_timeout_expired"] == True).sum())
# Out:
# Failed predictions: 227
# Success rate: 90.81%
# syntax_errors: 200
# is_less_than_limit_50000 == False: 20
# is_timeout_expired: 7
